# %% [markdown]
# # 🚀 CandiRank - Google Colab Sandbox
# Welcome to the interactive sandbox for **CandiRank**, built for the **Redrob AI Hiring Challenge**.
#
# This sandbox demonstrates the end-to-end execution of our two-stage ranking pipeline on a candidate sample.

# %% [markdown]
# ### 📦 Step 1: Clone Repository & Install Dependencies

# %%
# Clone the CandiRank repository
# !git clone https://github.com/chaitrali-code/CandiRank.git
# %cd CandiRank

# Install dependencies (mammoth, pdfkit, @xenova/transformers, compute-cosine-similarity, etc.)
# !npm install

# %% [markdown]
# ### 🧹 Step 2: Run Stage 1 (Behavioral Sieve & Honeypot Filter)
# Processes the candidates and filters out honeypot trap accounts.

# %%
# !node src/ranker.js

# %% [markdown]
# ### 🧠 Step 3: Run Stage 2 (Local Neural Embeddings & Semantic Cosine Similarity)
# Loads a local `all-MiniLM-L6-v2` transformer model via WebAssembly (runs entirely offline on CPU) to embed profiles and job description, then ranks the candidates.

# %%
# !node src/ranker_semantic.js

# %% [markdown]
# ### 📊 Step 4: Display Output CSV

# %%
# Display the top 10 candidates generated in the sandbox
import pandas as pd
df = pd.read_csv('data/team_CandiRank.csv')
df.head(10)
